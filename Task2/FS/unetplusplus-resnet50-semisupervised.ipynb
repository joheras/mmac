# %%
from fastai.basics import *
from fastai.vision import models
from fastai.vision.all import *
from fastai.metrics import *
from fastai.data.all import *
from fastai.callback import *
import segmentation_models_pytorch as smp


from pathlib import Path
import random

# %%
import torch
torch.cuda.set_device(0)

# %%
# %matplotlib inline
import numpy as np

# %%
number_of_the_seed = 2020

random.seed(number_of_the_seed)
set_seed(number_of_the_seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
path = Path("../../1. Classification of Myopic Maculopathy/Images/")
path_images = path/"TrainingSet"
path_labels = path/"Fuchs"

# %%
get_y_fn = lambda x: Path(str(x).replace("TrainingSet","Fuchs"))

# %%
codes = ['BG','FG']

# %%
monitor_training="dice_multi"
comp_training=np.greater

monitor_evaluating="dice"
comp_evaluating=np.greater

patience=5

# %%
from albumentations import (
    Compose,
    OneOf,
    ElasticTransform,
    GridDistortion, 
    OpticalDistortion,
    Flip,
    VerticalFlip,
    Rotate,
    Transpose,
    CLAHE,
    ShiftScaleRotate
)

# %%
class SegmentationAlbumentationsTransform(ItemTransform):
    split_idx = 0
    def __init__(self, aug): 
        self.aug = aug
    def encodes(self, x):
        img,mask = x
        aug = self.aug(image=np.array(img), mask=np.array(mask))
        return PILImage.create(aug["image"]), PILMask.create(aug["mask"])
    
transformPipeline=Compose([
                        Flip(p=0.5),
                        VerticalFlip(p=0.5),
                        Transpose(p=0.5),
                        Rotate(p=0.40,limit=180),GridDistortion(),CLAHE(),ShiftScaleRotate(),OpticalDistortion()
                    ],p=1)

transformPipeline=SegmentationAlbumentationsTransform(transformPipeline)

# %%
class TargetMaskConvertTransform(ItemTransform):
    def __init__(self): 
        pass
    def encodes(self, x):
        img,mask = x
        
        #Convert to array
        mask = np.array(mask)
        
        # Change 255 for 4
        mask[mask==255]=1
        
        # Back to PILMask
        mask = PILMask.create(mask)
        return img, mask

# %%
path_manual_img = path_images
path_manual_lbl = path_labels

# %%
fnames_manual = get_image_files(path_manual_img)
lbl_names_manual = get_image_files(path_manual_lbl)

# open and show image
img_f = fnames_manual[10]
print(img_f)
img = PILImage.create(img_f)
img.show(figsize=(5, 5))
# Out:
# ../../1. Classification of Myopic Maculopathy/Images/TrainingSet/mmac_task_1_train_0549.png
# <Axes: >

# %%
print(get_y_fn(img_f))
# Out:
# ../../1. Classification of Myopic Maculopathy/Images/Fuchs/mmac_task_1_train_0549.png

# %%
# mask = PILMask.create(get_y_fn(img_f))
# mask.show(figsize=(5, 5), alpha=1)

# %%
bs = 4

# %%
codes
# Out:
# ['BG', 'FG']

# %%
def my_get_image_files(path):
    return [Path(str(x).replace('Fuchs','TrainingSet')) for x in get_image_files(path)]

# %%
trainDB = DataBlock(blocks=(ImageBlock, MaskBlock(codes)),
                   get_items=my_get_image_files,
                   get_y=get_y_fn,
                   splitter=RandomSplitter(valid_pct=0.2),
                   item_tfms=[Resize((800,800)), TargetMaskConvertTransform(), transformPipeline],
                   batch_tfms=Normalize.from_stats(*imagenet_stats)
                  )

# %%
dlsTrain = trainDB.dataloaders(path_labels,bs=bs)

dlsTrain.show_batch(vmin=0,vmax=1,figsize=(12, 9))

# %%
model = smp.UnetPlusPlus(
    encoder_name="resnet50",        # choose encoder, e.g. mobilenet_v2 or efficientnet-b7
    encoder_weights="imagenet",     # use `imagenet` pre-trained weights for encoder initialization
    in_channels=3,                  # model input channels (1 for gray-scale images, 3 for RGB, etc.)
    classes=2,                      # model output channels (number of classes in your dataset)
td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.001147</td>
#       <td>0.000999</td>
#       <td>0.889023</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.001046</td>
#       <td>0.001146</td>
#       <td>0.874105</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.001125</td>
#       <td>0.001057</td>
#       <td>0.876762</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.001046</td>
#       <td>0.001052</td>
#       <td>0.876979</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.001006</td>
#       <td>0.001198</td>
#       <td>0.864206</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.000958</td>
#       <td>0.001007</td>
#       <td>0.900076</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.001029</td>
#       <td>0.000955</td>
#       <td>0.880310</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.000939</td>
#       <td>0.001193</td>
#       <td>0.862197</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.000979</td>
#       <td>0.001186</td>
#       <td>0.883691</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.001076</td>
#       <td>0.001225</td>
#       <td>0.863242</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.000981</td>
#       <td>0.001245</td>
#       <td>0.873126</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.000988</td>
#       <td>0.000962</td>
#       <td>0.884494</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.000881</td>
#       <td>0.001125</td>
#       <td>0.878147</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.000902</td>
#       <td>0.000966</td>
#       <td>0.868507</td>
#       <td
# Better model found at epoch 0 with dice_multi value: 0.47910444767627974.
# Better model found at epoch 1 with dice_multi value: 0.49676270014949286.
# Better model found at epoch 2 with dice_multi value: 0.5020946142252506.
# Better model found at epoch 5 with dice_multi value: 0.5230280662993018.
# Better model found at epoch 6 with dice_multi value: 0.7176774923114063.
# Better model found at epoch 7 with dice_multi value: 0.7581262502008809.
# Better model found at epoch 10 with dice_multi value: 0.7936453104303327.
# Better model found at epoch 13 with dice_multi value: 0.7952504432457176.
# Better model found at epoch 14 with dice_multi value: 0.8208321955193547.
# Better model found at epoch 15 with dice_multi value: 0.823555371667699.
# Better model found at epoch 18 with dice_multi value: 0.8602940103916996.
# Better model found at epoch 33 with dice_multi value: 0.8630609902635284.
# Better model found at epoch 41 with dice_multi value: 0.8740854669772108.
# Better model found at epoch 46 with dice_multi value: 0.8890227519068427.
# Better model found at epoch 51 with dice_multi value: 0.9000758172617319.

# %%
path = Path("./")
path_images = path/"1. Images/1. Training Set"
path_labels = path/"2. Groundtruths/1. Training Set"

# %%
get_y_fn = lambda x: Path(str(x).replace("1. Images","2. Groundtruths"))

# %%
trainDB = DataBlock(blocks=(ImageBlock, MaskBlock(codes)),
                   get_items=partial(get_image_files),
                   get_y=get_y_fn,
                   splitter=RandomSplitter(valid_pct=0.2),
                   item_tfms=[Resize((800,800)), TargetMaskConvertTransform(), transformPipeline],
                   batch_tfms=Normalize.from_stats(*imagenet_stats)
                  )

# %%
dlsTrain = trainDB.dataloaders(path_images,bs=bs)

dlsTrain.show_batch(vmin=0,vmax=1,figsize=(12, 9))

# %%
learn.dls = dlsTrain

# %%
fname="unetplusplus-resnet50-semi-v2"

callbacksFitBeforeUnfreeze = [
    ShowGraphCallback(),
    # EarlyStoppingCallback(monitor=monitor_training,comp=comp_training, patience=patience),
    SaveModelCallback(monitor=monitor_training,comp=comp_training,every_epoch=False,fname=fname)  
]
learn.fit_one_cycle(100, slice(1e-4,1e-3),cbs=callbacksFitBeforeUnfreeze)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice_multi</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.001790</td>
#       <td>0.001009</td>
#       <td>0.882612</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.001999</td>
#       <td>0.001057</td>
#       <td>0.879277</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.001883</td>
#       <td>0.001100</td>
#       <td>0.873980</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.001843</td>
#       <td>0.001097</td>
#       <td>0.873023</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.001773</td>
#       <td>0.001093</td>
#       <td>0.871664</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.001776</td>
#       <td>0.001073</td>
#       <td>0.867071</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.001775</td>
#       <td>0.001112</td>
#       <td>0.867516</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.001804</td>
#       <td>0.001074</td>
#       <td>0.867179</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0