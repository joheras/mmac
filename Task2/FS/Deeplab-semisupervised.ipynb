# %%
from fastai.basics import *
from fastai.vision import models
from fastai.vision.all import *
from fastai.metrics import *
from fastai.data.all import *
from fastai.callback import *
import segmentation_models_pytorch as smp


from pathlib import Path
import random

# %%
import torch
torch.cuda.set_device(1)

# %%
# %matplotlib inline
import numpy as np

# %%
number_of_the_seed = 2020

random.seed(number_of_the_seed)
set_seed(number_of_the_seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
path = Path("../../1. Classification of Myopic Maculopathy/Images/")
path_images = path/"TrainingSet"
path_labels = path/"Fuchs"

# %%
get_y_fn = lambda x: Path(str(x).replace("TrainingSet","Fuchs"))

# %%
codes = ['BG','FG']

# %%
monitor_training="dice_multi"
comp_training=np.greater

monitor_evaluating="dice"
comp_evaluating=np.greater

patience=5

# %%
from albumentations import (
    Compose,
    OneOf,
    ElasticTransform,
    GridDistortion, 
    OpticalDistortion,
    Flip,
    VerticalFlip,
    Rotate,
    Transpose,
    CLAHE,
    ShiftScaleRotate
)

# %%
class SegmentationAlbumentationsTransform(ItemTransform):
    split_idx = 0
    def __init__(self, aug): 
        self.aug = aug
    def encodes(self, x):
        img,mask = x
        aug = self.aug(image=np.array(img), mask=np.array(mask))
        return PILImage.create(aug["image"]), PILMask.create(aug["mask"])
    
transformPipeline=Compose([
                        Flip(p=0.5),
                        VerticalFlip(p=0.5),
                        Transpose(p=0.5),
                        Rotate(p=0.40,limit=180),GridDistortion(),CLAHE(),ShiftScaleRotate(),OpticalDistortion()
                    ],p=1)

transformPipeline=SegmentationAlbumentationsTransform(transformPipeline)

# %%
class TargetMaskConvertTransform(ItemTransform):
    def __init__(self): 
        pass
    def encodes(self, x):
        img,mask = x
        
        #Convert to array
        mask = np.array(mask)
        
        # Change 255 for 4
        mask[mask==255]=1
        
        # Back to PILMask
        mask = PILMask.create(mask)
        return img, mask

# %%
path_manual_img = path_images
path_manual_lbl = path_labels

# %%
fnames_manual = get_image_files(path_manual_img)
lbl_names_manual = get_image_files(path_manual_lbl)

# open and show image
img_f = fnames_manual[10]
print(img_f)
img = PILImage.create(img_f)
img.show(figsize=(5, 5))
# Out:
# ../../1. Classification of Myopic Maculopathy/Images/TrainingSet/mmac_task_1_train_0549.png
# <Axes: >

# %%
print(get_y_fn(img_f))
# Out:
# ../../1. Classification of Myopic Maculopathy/Images/Fuchs/mmac_task_1_train_0549.png

# %%
# mask = PILMask.create(get_y_fn(img_f))
# mask.show(figsize=(5, 5), alpha=1)

# %%
bs = 16

# %%
codes
# Out:
# ['BG', 'FG']

# %%
def my_get_image_files(path):
    return [Path(str(x).replace('Fuchs','TrainingSet')) for x in get_image_files(path)]

# %%
trainDB = DataBlock(blocks=(ImageBlock, MaskBlock(codes)),
                   get_items=my_get_image_files,
                   get_y=get_y_fn,
                   splitter=RandomSplitter(valid_pct=0.2),
                   item_tfms=[Resize((800,800)), TargetMaskConvertTransform(), transformPipeline],
                   batch_tfms=Normalize.from_stats(*imagenet_stats)
                  )

# %%
dlsTrain = trainDB.dataloaders(path_labels,bs=bs)

dlsTrain.show_batch(vmin=0,vmax=1,figsize=(12, 9))

# %%
model = smp.DeepLabV3Plus(
    encoder_name="resnet50",        # choose encoder, e.g. mobilenet_v2 or efficientnet-b7
    encoder_weights="imagenet",     # use `imagenet` pre-trained weights for encoder initialization
    in_channels=3,                  # model input channels (1 for gray-scale images, 3 for RGB, etc.)
    classes=2,                      # model output channels (number of classes in your dataset)
)

# %%
learn = Learner(dlsTrain,model,metrics=[DiceMulti()]).to_fp16()

# %%
fname="deeplab-resnet50-semi"

callbacksFitBeforeUnfreeze = [
    ShowGraphCallback(),
    # EarlyStoppingCallback(monitor=monitor_training,comp=comp_training, patience=patience),
    SaveModelCallback(monitor=monitor_training,comp=comp_training,every_epoch=False,fname=fname)  
]
learn.fit_one_cycle(100, slice(1e-4,1e-3),cbs=callbacksFitBeforeUnfreeze)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice_multi</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.949943</td>
#       <td>0.711776</td>
#       <td>0.007355</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.870737</td>
#       <td>0.736824</td>
#       <td>0.019993</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.774775</td>
#       <td>0.698244</td>
#       <td>0.325981</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.674559</td>
#       <td>0.552986</td>
#       <td>0.500545</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.580871</td>
#       <td>0.372167</td>
#       <td>0.498980</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.499575</td>
#       <td>0.334401</td>
#       <td>0.496531</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.430186</td>
#       <td>0.222259</td>
#       <td>0.499165</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.368596</td>
#       <td>0.219424</td>
#       <td>0.497395</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.313478</td>
#       <td>0.307983</td>
#       <td>0.496685</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.266712</td>
#       <td>0.097882</td>
#       <td>0.498860</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.226619</td>
#       <td>0.071827</td>
#       <td>0.499147</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.192717</td>
#       <td>0.055829</td>
#       <td>0.499211</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.164396</td>
#       <td>0.046399</td>
#       <td>0.499218</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.140527</td>
#       <td>0.055413</td>
#       <td>0.499016</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.120127</td>
#       <td>0.033493</td>
#       <td>0.499190</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.103030</td>
#       <td>0.029788</td>
#       <td>0.499218</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.088560</td>
#       <td>0.029465</td>
#       <td>0.619781</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.076139</td>
#       <td>0.024072</td>
#       <td>0.675019</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.065624</td>
#       <td>0.019616</td>
#       <td>0.780426</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.056699</td>
#       <td>0.016908</td>
#       <td>0.691279</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.049237</td>
#       <td>0.018341</td>
#       <td>0.785873</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.042787</td>
#       <td>0.015263</td>
#       <td>0.676513</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.037400</td>
#       <td>0.012741</td>
#       <td>0.795314</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.032779</td>
#       <td>0.013769</td>
#       <td>0.790355</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.028912</td>
#       <td>0.011290</td>
#       <td>0.794869</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.025474</td>
#       <td>0.010836</td>
#       <td>0.730645</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.022656</td>
#       <td>0.009449</td>
#       <td>0.802244</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.020224</td>
#       <td>0.010026</td>
#       <td>0.731816</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.018142</td>
#       <td>0.008046</td>
#       <td>0.828468</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.016602</td>
#       <td>0.009246</td>
#       <td>0.763469</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.014938</td>
#       <td>0.008953</td>
#       <td>0.711574</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.013523</td>
#       <td>0.007318</td>
#       <td>0.810756</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.012484</td>
#       <td>0.008869</td>
#       <td>0.724258</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.011702</td>
#       <td>0.007722</td>
#       <td>0.795530</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.010900</td>
#       <td>0.007338</td>
#       <td>0.830695</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.010174</td>
#       <td>0.007385</td>
#       <td>0.847750</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.009615</td>
#       <td>0.007445</td>
#       <td>0.736929</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.009140</td>
#       <td>0.005915</td>
#       <td>0.852205</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.008591</td>
#       <td>0.006923</td>
#       <td>0.775865</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.007947</td>
#       <td>0.005421</td>
#       <td>0.876383</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.007417</td>
#       <td>0.005074</td>
#       <td>0.862818</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.007011</td>
#       <td>0.005010</td>
#       <td>0.862890</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.006653</td>
#       <td>0.005180</td>
#       <td>0.874923</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.006281</td>
#       <td>0.004732</td>
#       <td>0.864840</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.005949</td>
#       <td>0.005760</td>
#       <td>0.785436</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.005692</td>
#       <td>0.004654</td>
#       <td>0.873572</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.005587</td>
#       <td>0.005016</td>
#       <td>0.830281</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.005427</td>
#       <td>0.006402</td>
#       <td>0.772701</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.005283</td>
#       <td>0.004973</td>
#       <td>0.876617</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.005126</td>
#       <td>0.004369</td>
#       <td>0.874003</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.004938</td>
#       <td>0.004795</td>
#       <td>0.844285</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.004713</td>
#       <td>0.004034</td>
#       <td>0.876831</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.004630</td>
#       <td>0.004642</td>
#       <td>0.847063</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.004547</td>
#       <td>0.005567</td>
#       <td>0.783445</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.004476</td>
#       <td>0.004874</td>
#       <td>0.849077</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.004310</td>
#       <td>0.005345</td>
#       <td>0.828511</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.004162</td>
#       <td>0.004243</td>
#       <td>0.882375</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.004105</td>
#       <td>0.005072</td>
#       <td>0.849471</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.004032</td>
#       <td>0.003933</td>
#       <td>0.872593</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.003919</td>
#       <td>0.003844</td>
#       <td>0.884966</td>
#       <td
# Better model found at epoch 0 with dice_multi value: 0.00735518891593104.
# Better model found at epoch 1 with dice_multi value: 0.019993146510812836.
# Better model found at epoch 2 with dice_multi value: 0.32598088032498956.
# Better model found at epoch 3 with dice_multi value: 0.5005452848723683.
# Better model found at epoch 16 with dice_multi value: 0.6197806842762232.
# Better model found at epoch 17 with dice_multi value: 0.6750185440356433.
# Better model found at epoch 18 with dice_multi value: 0.7804264340822922.
# Better model found at epoch 20 with dice_multi value: 0.7858727814778246.
# Better model found at epoch 22 with dice_multi value: 0.7953143483296998.
# Better model found at epoch 26 with dice_multi value: 0.8022438233022654.
# Better model found at epoch 28 with dice_multi value: 0.8284680882927709.
# Better model found at epoch 34 with dice_multi value: 0.830695208155679.
# Better model found at epoch 35 with dice_multi value: 0.8477498850497338.
# Better model found at epoch 37 with dice_multi value: 0.8522047158215105.
# Better model found at epoch 39 with dice_multi value: 0.8763825779951115.
# Better model found at epoch 48 with dice_multi value: 0.8766168922712576.
# Better model found at epoch 51 with dice_multi value: 0.8768309481124112.
# Better model found at epoch 56 with dice_multi value: 0.8823750446500382.
# Better model found at epoch 59 with dice_multi value: 0.8849660753118023.
# Better model found at epoch 63 with dice_multi value: 0.8896492191160283.
# Better model found at epoch 68 with dice_multi value: 0.9087297396545645.

# %%
path = Path("./")
path_images = path/"1. Images/1. Training Set"
path_labels = path/"2. Groundtruths/1. Training Set"

# %%
get_y_fn = lambda x: Path(str(x).replace("1. Images","2. Groundtruths"))

# %%
trainDB = DataBlock(blocks=(ImageBlock, MaskBlock(codes)),
                   get_items=partial(get_image_files),
                   get_y=get_y_fn,
                   splitter=RandomSplitter(valid_pct=0.2),
                   item_tfms=[Resize((800,800)), TargetMaskConvertTransform(), transformPipeline],
                   batch_tfms=Normalize.from_stats(*imagenet_stats)
                  )

# %%
dlsTrain = trainDB.dataloaders(path_images,bs=bs)

dlsTrain.show_batch(vmin=0,vmax=1,figsize=(12, 9))

# %%
learn.dls = dlsTrain

# %%
fname="deeplab-resnet50-semi-v2"

callbacksFitBeforeUnfreeze = [
    ShowGraphCallback(),
    # EarlyStoppingCallback(monitor=monitor_training,comp=comp_training, patience=patience),
    SaveModelCallback(monitor=monitor_training,comp=comp_training,every_epoch=False,fname=fname)  
]
learn.fit_one_cycle(100, slice(1e-4,1e-3),cbs=callbacksFitBeforeUnfreeze)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice_multi</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.006333</td>
#       <td>0.008653</td>
#       <td>0.913358</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.005665</td>
#       <td>0.008618</td>
#       <td>0.913656</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.005953</td>
#       <td>0.008566</td>
#       <td>0.913746</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.005611</td>
#       <td>0.008569</td>
#       <td>0.913279</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.005788</td>
#       <td>0.008610</td>
#       <td>0.912041</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.005830</td>
#       <td>0.008671</td>
#       <td>0.910406</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.005586</td>
#       <td>0.008823</td>
#       <td>0.908529</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.005492</td>
#       <td>0.009130</td>
#       <td>0.902997</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.005414</td>
#       <td>0.009783</td>
#       <td>0.892026</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.005300</td>
#       <td>0.010540</td>
#       <td>0.879718</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.005212</td>
#       <td>0.010503</td>
#       <td>0.878379</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.005093</td>
#       <td>0.010011</td>
#       <td>0.885090</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.005025</td>
#       <td>0.010307</td>
#       <td>0.880532</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.004905</td>
#       <td>0.012885</td>
#       <td>0.841836</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.004813</td>
#       <td>0.017335</td>
#       <td>0.788265</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.004861</td>
#       <td>0.010347</td>
#       <td>0.881325</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.004890</td>
#       <td>0.009495</td>
#       <td>0.895150</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.004849</td>
#       <td>0.013078</td>
#       <td>0.840915</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.004767</td>
#       <td>0.014479</td>
#       <td>0.828692</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.004768</td>
#       <td>0.009840</td>
#       <td>0.902873</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.004745</td>
#       <td>0.009936</td>
#       <td>0.893937</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.004731</td>
#       <td>0.012611</td>
#       <td>0.860859</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.004760</td>
#       <td>0.013286</td>
#       <td>0.873475</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.004801</td>
#       <td>0.022907</td>
#       <td>0.717209</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.004835</td>
#       <td>0.025134</td>
#       <td>0.713786</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.004864</td>
#       <td>0.012239</td>
#       <td>0.880621</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.004831</td>
#       <td>0.013335</td>
#       <td>0.862221</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.004819</td>
#       <td>0.013307</td>
#       <td>0.871886</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.004791</td>
#       <td>0.009614</td>
#       <td>0.904973</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.004745</td>
#       <td>0.009367</td>
#       <td>0.899547</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.004730</td>
#       <td>0.009603</td>
#       <td>0.897355</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.004715</td>
#       <td>0.009563</td>
#       <td>0.901134</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.004739</td>
#       <td>0.008872</td>
#       <td>0.905705</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.004691</td>
#       <td>0.011485</td>
#       <td>0.878046</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.004685</td>
#       <td>0.010002</td>
#       <td>0.895237</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.004685</td>
#       <td>0.010330</td>
#       <td>0.895782</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.004644</td>
#       <td>0.014956</td>
#       <td>0.852487</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.004584</td>
#       <td>0.016977</td>
#       <td>0.830095</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.004790</td>
#       <td>0.020494</td>
#       <td>0.764532</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.005049</td>
#       <td>0.016229</td>
#       <td>0.790650</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.005149</td>
#       <td>0.020017</td>
#       <td>0.767738</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.005212</td>
#       <td>0.031134</td>
#       <td>0.682128</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.005233</td>
#       <td>0.036479</td>
#       <td>0.594270</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.005316</td>
#       <td>0.024600</td>
#       <td>0.790538</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.005338</td>
#       <td>0.022882</td>
#       <td>0.819927</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.005338</td>
#       <td>0.019584</td>
#       <td>0.809283</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.005401</td>
#       <td>0.014705</td>
#       <td>0.841148</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.005397</td>
#       <td>0.017299</td>
#       <td>0.795578</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.005447</td>
#       <td>0.020808</td>
#       <td>0.740232</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.005468</td>
#       <td>0.017230</td>
#       <td>0.795799</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.005436</td>
#       <td>0.023616</td>
#       <td>0.756329</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.005397</td>
#       <td>0.031771</td>
#       <td>0.706818</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.005372</td>
#       <td>0.025536</td>
#       <td>0.735026</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.005332</td>
#       <td>0.015196</td>
#       <td>0.830474</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.005300</td>
#       <td>0.011964</td>
#       <td>0.878767</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.005225</td>
#       <td>0.011830</td>
#       <td>0.880311</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.005188</td>
#       <td>0.011609</td>
#       <td>0.883903</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.005182</td>
#       <td>0.010355</td>
#       <td>0.902346</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.005096</td>
#       <td>0.010216</td>
#       <td>0.903825</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.005058</td>
#       <td>0.011783</td>
#       <td>0.882849</td>
#       <td
# Better model found at epoch 0 with dice_multi value: 0.9133577327900761.
# Better model found at epoch 1 with dice_multi value: 0.9136558493721803.
# Better model found at epoch 2 with dice_multi value: 0.913746237396431.

# %%
aux=learn.model
aux=aux.cpu()

torch.save(aux,'deeplab-fuchs-semi.pth')
